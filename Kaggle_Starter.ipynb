# %% [markdown]
# # EEG-AD Pipeline - Kaggle Starter Notebook
#
# This notebook runs the Hybrid Multimodal Deep Learning pipeline (EEGNet + CViT + GNN).
#
# ## Setup Instructions
#
# 1. **Upload Code**: Upload `neurofusion_kaggle.zip` as a Kaggle Dataset (e.g., name it `neurofusion-code`).
# 2. **Upload Data**: Ensure your BIDS EEG dataset is also added to the notebook.
# 3. **Update Paths**: Change the paths in the cell below to match your dataset folder names.

# %%
import sys
import os

# 1. Define Paths
CODE_DATASET_DIR = '/kaggle/input/neurofusion-code'
EEG_DATASET_DIR = '/kaggle/input/open-neuro-dataset-alzheimer'

# 2. Add code directory to Python path
sys.path.append(CODE_DATASET_DIR)

print("Environment Setup Complete.")

# %% [markdown]
# ## 3. Install Dependencies
# Ensure PyTorch Geometric and other libraries are installed.

# %%
# !pip install mne numpy scipy scikit-learn torch torchvision torch-geometric joblib

# %% [markdown]
# ## 4. Run the Hybrid Pipeline
# This script loads data, extracts CWT Scalograms and Connectivity matrices, and trains the FusionNet architecture.

# %%
# !python {CODE_DATASET_DIR}/run_pipeline.py --data_dir {EEG_DATASET_DIR} --epochs 60 --batch_size 64

# %%
# !python {CODE_DATASET_DIR}/run_pipeline.py --data_dir {EEG_DATASET_DIR} --epochs 60 --batch_size 64
